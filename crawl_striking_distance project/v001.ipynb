# %%
import pandas as pd

# %%
striking_df = pd.read_csv('keywords_within_striking_distance.csv')
crawl_df = pd.read_csv('WSkeywords - ScreamingFrog Crawl.csv')
internal_df = pd.read_csv('WSkeywords - Internal data.csv')

# %%
striking_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   URL                    577 non-null    object
#  1   Title                  575 non-null    object
#  2   H1                     573 non-null    object
#  3   Striking Dist. Vol     577 non-null    int64
#  4   KWs in Striking Dist.  577 non-null    int64
#  5   KW1                    577 non-null    object
#  6   KW1 Vol                577 non-null    int64
#  7   KW1 in Title           577 non-null    bool
#  8   KW1 in H1              577 non-null    bool
#  9   KW1 in Copy            577 non-null    bool
#  10  KW2                    449 non-null    object
#  11  KW2 Vol                449 non-null    float64
#  12  KW2 in Title           449 non-null    object
#  13  KW2 in H1              449 non-null    object
# ...

# %%
striking_df.head()
# Out:
#                                                  URL  \
# 0  https://www.wealthsimple.com/en-ca/learn/how-m...
# 1  https://www.wealthsimple.com/en-ca/tool/tax-ca...
# 2     https://www.wealthsimple.com/en-ca/product/tax
# 3  https://www.wealthsimple.com/en-ca/learn/tfsa-...
# 4  https://www.wealthsimple.com/en-ca/learn/tax-b...
#
#                                                Title  \
# 0  cpp retirement pay dates for 2022: how much cp...
# 1                  2021 income tax calculator canada
# 2  wealthsimple tax | free online tax filing soft...
# 3  the tfsa limit for 2022 (and — why not? — all ...
# 4  canada tax brackets 2021 - 2022 | federal & pr...
#
#                                                   H1  Striking Dist. Vol  \
# 0  cpp retirement pay dates for 2022: how much cp...              306230
# 1                  2021 income tax calculator canada              266010
# 2                                   wealthsimple tax              236010
# ...

# %%
crawl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 38 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   URL                             1566 non-null   object
#  1   Title 1                         1566 non-null   object
#  2   Title 1 Length                  1566 non-null   int64
#  3   Title 1 Pixel Width             1566 non-null   int64
#  4   Meta Description 1              1563 non-null   object
#  5   Meta Description 1 Length       1566 non-null   int64
#  6   Meta Description 1 Pixel Width  1565 non-null   float64
#  7   H1-1                            1533 non-null   object
#  8   H1-1 Length                     1565 non-null   float64
#  9   H1-2                            40 non-null     object
#  10  H1-2 Length                     1566 non-null   object
#  11  H2-1                            1562 non-null   object
# ...

# %%
crawl_df.head()
# Out:
#                                                  URL  \
# 0  https://www.wealthsimple.com/en-ca/portfolio-r...
# 1         https://www.wealthsimple.com/en-ca/pricing
# 2            https://www.wealthsimple.com/en-ca/work
# 3   https://www.wealthsimple.com/en-ca/product/trade
# 4    https://www.wealthsimple.com/en-ca/product/cash
#
#                                              Title 1  Title 1 Length  \
# 0                    Portfolio Review | Wealthsimple              31
# 1  Wealthsimple Plans: Compare our Investing Plan...              54
# 2             Wealthsimple Work: Low-fee Group RRSPs              38
# 3  Wealthsimple Trade | $0 Commission Stock Marke...              63
# 4  Wealthsimple Cash | Send, Spend or Receive Mon...              58
#
#    Title 1 Pixel Width                                 Meta Description 1  \
# 0                  279  Get on track with a Wealthsimple Portfolio Rev...
# 1                  513  Compare all Wealthsimple plans and fees. Choos...
# ...

# %%
internal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   URL            823 non-null    object
#  1   visitors_web_  823 non-null    float64
#  2   registrants_   823 non-null    float64
#  3   clients_       823 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 25.8+ KB

# %%
internal_df.head()
# Out:
#                                                  URL  visitors_web_  \
# 0  https://www.wealthsimple.com/en-ca/learn/how-t...      122900.47
# 1  https://www.wealthsimple.com/en-ca/learn/how-t...       46954.80
# 2  https://www.wealthsimple.com/en-ca/learn/robin...       37615.46
# 3  https://www.wealthsimple.com/en-ca/learn/what-...       63325.11
# 4  https://www.wealthsimple.com/en-ca/learn/best-...       32588.34
#
#    registrants_  clients_
# 0       5245.70   2361.51
# 1       3408.84   1736.74
# 2       2360.84   1446.19
# 3       1288.79    956.27
# 4       1568.54    906.45

# %%
striking_crawl = pd.merge(striking_df, crawl_df, how='left', left_on=['URL'], right_on=['URL'])

# %%
striking_crawl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 577 entries, 0 to 576
# Data columns (total 67 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   URL                             577 non-null    object
#  1   Title                           575 non-null    object
#  2   H1                              573 non-null    object
#  3   Striking Dist. Vol              577 non-null    int64
#  4   KWs in Striking Dist.           577 non-null    int64
#  5   KW1                             577 non-null    object
#  6   KW1 Vol                         577 non-null    int64
#  7   KW1 in Title                    577 non-null    bool
#  8   KW1 in H1                       577 non-null    bool
#  9   KW1 in Copy                     577 non-null    bool
#  10  KW2                             449 non-null    object
#  11  KW2 Vol                         449 non-null    float64
# ...

# %%
striking_crawl.head()
# Out:
#                                                  URL  \
# 0  https://www.wealthsimple.com/en-ca/learn/how-m...
# 1  https://www.wealthsimple.com/en-ca/tool/tax-ca...
# 2     https://www.wealthsimple.com/en-ca/product/tax
# 3  https://www.wealthsimple.com/en-ca/learn/tfsa-...
# 4  https://www.wealthsimple.com/en-ca/learn/tax-b...
#
#                                                Title  \
# 0  cpp retirement pay dates for 2022: how much cp...
# 1                  2021 income tax calculator canada
# 2  wealthsimple tax | free online tax filing soft...
# 3  the tfsa limit for 2022 (and — why not? — all ...
# 4  canada tax brackets 2021 - 2022 | federal & pr...
#
#                                                   H1  Striking Dist. Vol  \
# 0  cpp retirement pay dates for 2022: how much cp...              306230
# 1                  2021 income tax calculator canada              266010
# 2                                   wealthsimple tax              236010
# ...

# %%
striking_crawl.shape
# Out:
# (577, 67)

# %%
striking_crawl_internal = pd.merge(striking_crawl, internal_df, how='left', left_on=['URL'], right_on=['URL'])

# %%
striking_crawl_internal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 577 entries, 0 to 576
# Data columns (total 70 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   URL                             577 non-null    object
#  1   Title                           575 non-null    object
#  2   H1                              573 non-null    object
#  3   Striking Dist. Vol              577 non-null    int64
#  4   KWs in Striking Dist.           577 non-null    int64
#  5   KW1                             577 non-null    object
#  6   KW1 Vol                         577 non-null    int64
#  7   KW1 in Title                    577 non-null    bool
#  8   KW1 in H1                       577 non-null    bool
#  9   KW1 in Copy                     577 non-null    bool
#  10  KW2                             449 non-null    object
#  11  KW2 Vol                         449 non-null    float64
# ...

# %%
striking_crawl_internal.head()
# Out:
#                                                  URL  \
# 0  https://www.wealthsimple.com/en-ca/learn/how-m...
# 1  https://www.wealthsimple.com/en-ca/tool/tax-ca...
# 2     https://www.wealthsimple.com/en-ca/product/tax
# 3  https://www.wealthsimple.com/en-ca/learn/tfsa-...
# 4  https://www.wealthsimple.com/en-ca/learn/tax-b...
#
#                                                Title  \
# 0  cpp retirement pay dates for 2022: how much cp...
# 1                  2021 income tax calculator canada
# 2  wealthsimple tax | free online tax filing soft...
# 3  the tfsa limit for 2022 (and — why not? — all ...
# 4  canada tax brackets 2021 - 2022 | federal & pr...
#
#                                                   H1  Striking Dist. Vol  \
# 0  cpp retirement pay dates for 2022: how much cp...              306230
# 1                  2021 income tax calculator canada              266010
# 2                                   wealthsimple tax              236010
# ...

# %%
striking_crawl_internal.shape
# Out:
# (577, 70)

# %%
striking_crawl_internal.to_csv('FINAL.csv', index=False)
